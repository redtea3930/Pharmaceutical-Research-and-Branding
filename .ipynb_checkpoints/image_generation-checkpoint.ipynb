# %%
# Ran in Google Colab

# %%
# Installations
# !pip install git+https://github.com/huggingface/diffusers
# !pip install transformers accelerate safetensors
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-4wcd1nfk
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-4wcd1nfk
#   Resolved https://github.com/huggingface/diffusers to commit 1328aeb274610f492c10a246ffba0bc4de8f689b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.7 MB/s eta 0:00:00
# ...
#   Created wheel for diffusers: filename=diffusers-0.23.0.dev0-py3-none-any.whl size=1673095 sha256=4317cfeff52a12bd9417cce28b32facc0a997714bf0d46e775e1bcc0e67d1896
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qdzfctt0/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# ...

# %%
# Mounting Google Drive to save output files to temporary file storage
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Instantiate model
from diffusers import StableDiffusionXLPipeline
import torch
pipe = StableDiffusionXLPipeline.from_pretrained("segmind/SSD-1B", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# StableDiffusionXLPipeline {
#   "_class_name": "StableDiffusionXLPipeline",
#   "_diffusers_version": "0.23.0.dev0",
#   "_name_or_path": "segmind/SSD-1B",
#   "force_zeros_for_empty_prompt": true,
#   "scheduler": [
#     "diffusers",
#     "EulerDiscreteScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "text_encoder_2": [
#     "transformers",
#     "CLIPTextModelWithProjection"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "tokenizer_2": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
# ...

# %%
# Generate image
prompt = "A blue oval, containing pink letters 'STL', surrounded by a white background. 1990's aesthetic" # Your prompt here
neg_prompt = "complex, 3D" # Negative prompt here
image = pipe(prompt=prompt, negative_prompt=neg_prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Save image
image.save("serenitall_logo.png")
